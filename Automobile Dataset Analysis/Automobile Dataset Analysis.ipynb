# %% [markdown]
# # Case Study : Automobile Dataset Analysis using Python

# %% [raw]
# Dataset Name : automobile.csv
# Dataset Link : Null
# Date : 19/07/2022 - 23/07/2022

# %% [markdown]
# # Project Main Objective
#
# - **Analyze the car dataset and find Trend and Pattern related to the cars**.
#
#
#
# # Project steps are
# 1. Data Collectiion
# 2. Data Understanding
# 3. Data Preprocessing ( Handling Missing values, Cleaning the messsy data)
# 4. Exploratory Data Analysis
#     a) Handling missing values
#     b) Cleaning the data
# 4. Report/Conclusion

# %% [markdown]
# ### Importing necessary libraries

# %%
# remove warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np, pandas as pd, seaborn as sns, matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
sns.set(color_codes=True)

# %% [markdown]
# ## 1. Collecting Data

# %%
df = pd.read_csv("Automobile+%281%29.csv")
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %% [markdown]
# ## 2. Understanding of Data

# %%
df.shape
# Out:
# (201, 26)

# %%
df.isna().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %%
# describe 
df.describe()
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055
# std      1.254802          33.572966    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.329701    3.261741
# std      2.447822   517.296727    41.546834    0.268166    0.317875
# ...

# %% [markdown]
# `insight`
#
# - In this dataset contains **201 rows and 26 columms**.
# - There is **no missing values** in this dataset.

# %% [markdown]
# ## 3. Data Preprocessing

# %%
# missing value percentage
df.isna().sum()*100/len(df)
# Out:
# symboling              0.0
# normalized_losses      0.0
# make                   0.0
# fuel_type              0.0
# aspiration             0.0
# number_of_doors        0.0
# body_style             0.0
# drive_wheels           0.0
# engine_location        0.0
# wheel_base             0.0
# length                 0.0
# width                  0.0
# height                 0.0
# curb_weight            0.0
# engine_type            0.0
# number_of_cylinders    0.0
# engine_size            0.0
# fuel_system            0.0
# bore                   0.0
# stroke                 0.0
# compression_ratio      0.0
# horsepower             0.0
# peak_rpm               0.0
# city_mpg               0.0
# highway_mpg            0.0
# price                  0.0
# dtype: float64

# %% [markdown]
#  `Insight`
#
# - **Dataset have no missing values**. All thing are perfectly.

# %% [markdown]
# ## 4. EDA ( Exploratory Data Analysis)

# %% [markdown]
# ### 1 Univariate Distribution Analysis

# %% [markdown]
# #### 1.1 Engine Size

# %%
# mean of Engine Size 
df.engine_size.mean()
# Out:
# 126.87562189054727

# %%
# maximum engine size
df.engine_size.max()
# Out:
# 326

# %%
plt.figure(figsize=(16, 9) )
sns.displot(df.engine_size, kde=True, rug=True, color="brown")
plt.show()

# %% [markdown]
# `insight`
#
# - As the engine size increase then Count of vehical is Decreases but a specific point of **126.87562189054727** then count gradually Decrease.
# - The Engine size is Increases but the Count decrease.

# %% [markdown]
# #### 1.2 Maker

# %%
plt.figure(figsize=(16,9))
plt.title("Market Share of Brand", size=20)
df.make.value_counts().plot.pie(autopct="%0.2f")
plt.savefig("Market Share of Brand.png")
plt.show()

# %% [markdown]
# `insight`
#
# - A big market share keep by the **toyota (15.92)**
# - **Top 3 brand capture the 1/3 market which is 33.34%**.

# %% [markdown]
# #### 1.3 Horsepower

# %%
# mean of Engine Size 
print(f"Mean horsepower is : {df.horsepower.mean()}  \nStandard Deviation is : {df.horsepower.std()}")
# Out:
# Mean horsepower is : 103.2636815920398
# Standard Deviation is : 37.38937181042373

# %%
df[df["horsepower"] > 200].value_counts().sum()
# Out:
# 4

# %%
plt.figure(figsize=(16, 9) )
sns.displot(df.horsepower, palette="viridis", kde=True)
plt.title("Distribution of Horsepower", size=20)
plt.savefig("Distribution of horsepower.png")
plt.show()

# %% [markdown]
# `insight`
# - **Most of the Vehicals fall under the range of 50 to 100 Horsepower**. Means the Most no of vehicals are in 50-100 horsepower Which is comparatibly is higer than other horsepower range.
# - Very Less count of vechical which horsepower is Greater than 200.**(4 vechical that have more than 200 horsepower engine).**.

# %% [markdown]
# #### 1.4 Normalized Losses

# %%
loss = df.normalized_losses.value_counts()
loss
# Out:
# 161    16
# 168     9
# 128     9
# 91      8
# 150     7
# 134     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 103     5
# 122     5
# 115     5
# 95      5
# 149     4
# 137     4
# 118     4
# 110     4
# 129     4
# 106     4
# 93      4
# 148     4
# 139     3
# 101     3
# 132     3
# 154     3
# 119     3
# 83      3
# 140     3
# 125     3
# 192     2
# 197     2
# 89      2
# 87      2
# 158     2
# 194     2
# 108     2
# 81      2
# 153     2
# 164     2
# 113     2
# 145     2
# 188     2
# 133     1
# 90      1
# 256     1
# 78      1
# 77      1
# 121     1
# 186     1
# 141     1
# 98      1
# 231     1
# 105     1
# 107     1
# 142     1
# Name: normalized_losses, dtype: int64

# %%
loss = df.normalized_losses.value_counts()
plt.figure(figsize=(16, 9) )
plt.title("Count of Losses vs Losses Values",size=20)
color = sns.color_palette("hot")
loss.plot.bar(color=color)
plt.savefig("Frequencies of Normalize losses.png")
plt.show()

# %% [markdown]
# `insight`
#
# - **Maximum loss occurs 16 times** which is heavy losses and the Losses value is 161.
# - **Minimum loss occurs 1 time** which is very low and the Losses value is 142.

# %% [markdown]
# #### 1.5 Engine Location

# %%
df.engine_location.value_counts()
# Out:
# front    198
# rear       3
# Name: engine_location, dtype: int64

# %%
plt.rcParams["figure.figsize"]= (9,6)
sns.set_style("dark")
plt.title("Percentage of Rear vs Front Engines",size=20, color="brown")
plt.pie(df.engine_location.value_counts(), colors= sns.color_palette("hsv"), shadow=True,autopct="%0.2f",wedgeprops = {'linewidth': 3} )
plt.legend([ "Front", "Rear"])
plt.savefig("Percentage of Rear vs Front.png")
plt.show()

# %% [markdown]
# `insight`
#
# - Pie chart is clearly shown that **Most of the Vehical are made up with Font Engine**, Which share is 98.51%.
# - **Rear Engine Vehical is very less compared to Front Engine Vehical**.
# - According to Statistics, **Manufacturing of Front Engine vehical is Much More**.

# %% [markdown]
# #### 1.6. Compression Ratio

# %% [markdown]
# **A higher compression ratio (CR) is beneficial for engines.** That's because the higher ratio allows for an engine to **extract more energy from the combustion process due to better thermal efficiency**. Higher compression ratios allow the same combustion temperatures to be achieved with less fuel

# %%
max((df.compression_ratio))
# Out:
# 23.0

# %%
df.compression_ratio.value_counts()
# Out:
# 9.00     46
# 9.40     26
# 8.50     14
# 9.50     13
# 9.30     11
# 8.70      9
# 8.00      8
# 9.20      8
# 7.00      6
# 8.60      5
# 21.00     5
# 8.40      5
# 7.50      5
# 23.00     5
# 21.50     4
# 7.60      4
# 9.60      3
# 22.50     3
# 8.30      3
# 8.80      3
# 10.00     2
# 7.70      2
# 8.10      2
# 9.10      1
# 9.31      1
# 7.80      1
# 9.41      1
# 21.90     1
# 22.00     1
# 22.70     1
# 10.10     1
# 11.50     1
# Name: compression_ratio, dtype: int64

# %%
plt.figure(figsize=(16, 9) )
# pie plot
plt.subplot(1,2,1)
plt.pie(df.compression_ratio.value_counts(),shadow=True, autopct="%0.2f")
# plt.legend(df.compression_ratio.value_counts(), loc=1)


# horizontal barplot
plt.subplot(1,2,2)
df.compression_ratio.value_counts(ascending=True).plot.barh()
plt.title("Compression Ration of Vehicles", size=20)
plt.legend()
plt.savefig("Compression Ration of Vehical.png")
plt.show()

# %% [markdown]
# `insight`
#
# - **9.0 Compression ratio vehical have 22.89%**. Which is more than other compression ratio. **9.0 is the Standard Recommendation** for engine to ensure safety.
# - **9.40 is best after the 9.0 Compression ratio vehical which have 12.94%**
# - **Best Compression Ratio is between 8.70-9.50**.

# %% [markdown]
# #### 1.7. City Mileage

# %%
df.city_mpg.mean()
# Out:
# 25.17910447761194

# %%
plt.figure(figsize=(16, 9) )
df.city_mpg.hist(color="blue")
df.highway_mpg.hist(color="red")
plt.title("Distribution of MPG on city vs highway", size=20)
plt.legend(["MPG on City","MPG on Highway"])
plt.savefig("Distribution of MPG on city vs highway.png")
plt.show()

# %% [markdown]
# `insight`
#
# - **25 mph is the average speed in City**. In rare case vehical give 49 mph speed.
# - **Mpg on high is high and highesh mpg is 50+**.

# %% [markdown]
# ### 2 Bivariate Analysis

# %% [markdown]
# Bivariate Analysis is use for **finding the relationship between two variable or features**.

# %% [markdown]
# #### 2.1 Engine_size vs Horsepower ( Scatterplot , Jointplot, Kernal Density Estimation)

# %% [markdown]
# 1. Scatterplot

# %%
plt.rcParams["figure.figsize"]=(16,9)

# Scatter plot
sns.jointplot(data=df,  x=df.engine_size, y=df.horsepower,kind="scatter")
# plt.xlabel("engine_size", size=20, color="Green")
# plt.ylabel("horsepower", size=20, color="Green")
plt.savefig("Scatter Engine vs Horsepower.png")
plt.show()

# %% [raw]
# 2. Hex bin plot

# %%
# hex bin plots
sns.jointplot(data=df,  x=df.engine_size, y=df.horsepower,kind="hex")
plt.savefig("Hex bin plot Engine vs Horsepower.png")
plt.xticks(np.array([]))
# Out:
# ([], [])

# %% [markdown]
# 3. Kernal Density Estimation

# %%
# Kde plot
sns.jointplot(x=df.engine_size, y=df.horsepower,kind="kde")
plt.savefig("Kernel Density Estimation Engine vs Horsepower.png")
plt.show()

# %% [markdown]
# 4. Regression Plot

# %%
# Reg plot
sns.jointplot(data=df,  x=df.engine_size, y=df.horsepower,kind="reg")
plt.savefig("Regresson plot Engine vs Horsepower.png")
plt.show()

# %% [markdown]
# `insight`
#
# - All graph shows that the **high density at 75 horsepower and 100 engine_size**
# - Regression plot is shows **horsepower is depend on the  engine size** of vehical.

# %% [markdown]
# #### 2.2 Mileage vs Number_of_cylinders ( Scatterplot , Jointplot, Kernal Density Estimation)

# %%
sns.barplot(x=df.number_of_cylinders, y=df.highway_mpg)
plt.savefig("Bar plot Engine vs Horsepower.png")
plt.show()
# Out:
# <AxesSubplot:xlabel='number_of_cylinders', ylabel='highway_mpg'>

# %% [markdown]
# `insight`
#
# - **No of 3 Cylinder is very high. but no of 8 cylinder is low milege**.
# - Many other factors include:
#     - Body Weights of Vehical
#     - Which type of engine use.
#     - Depend on the Fuel Type.
#     - Speed of Vehical

# %% [markdown]
# #### 2.3 Engine_Size vs Price

# %%
df.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
engine = df.engine_size.value_counts()
engine.head(1)
# Out:
# 122    15
# Name: engine_size, dtype: int64

# %%
sns.set_theme(style="whitegrid")
sns.violinplot(df.engine_size, df.price)
plt.savefig("violinplot of Engine Size vs Price.png")
plt.show()

# %% [markdown]
# `insight`
#
# - **Engine size is increase as well as Price is also increased**.
# - **Most Perfect engine size at perfect price is 122 engine size**.

# %% [markdown]
# #### 2.4 Fuel system type

# %%
df.fuel_system.value_counts(ascending=True).plot.barh({"size":20,'colors':[sns.color_palette("hot")]})
plt.savefig("barplot of Fuel system type.png")
plt.show()

# %% [markdown]
# `ìnsight`
#
# - Mostly uses two type of fuel engine **(mpfi and 2bbl)**
# - **Very Few type of spfi engines**.

# %% [markdown]
# #### 2.5 Comparision of fuel system on mpg variable (city_mpg, highway_mpg)

# %%
(df.city_mpg.median(), df.highway_mpg.median())
# Out:
# (24.0, 30.0)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))


sns.boxplot(data=df,  x=df.fuel_type, y=df.city_mpg,ax=ax1)
ax1.set_title("Mpg on City", size=20)

sns.boxplot(data=df,  x=df.fuel_type, y=df.highway_mpg,ax=ax2)
ax2.set_title("Mpg on Highway", size=20)

plt.savefig("Histogram of mpg on city vs  highway.png")
plt.show()

# %% [markdown]
# `Insight`
#
# - **Mpg for GAS increase on highway** which is better than mpg on city. but **Mpg for diesel is same as city**.

# %% [markdown]
# ## Basic Terminologies

# %% [markdown]
# A **Stroke** is when the piston moves from the top center to the bottom of the cylinder. During a combustion cycle, while the piston moves down the cylinder, it captures air and gas. As the piston moves back up to the top, the exhaust valve opens to expel the exhaust.
#
#
# **Bore** is the inner diameter of the cylinder. The volume at bottom dead centre (VBDC) is defined as the volume occupied between the cylinder head and the piston face when the piston is farthest from the cylinder head.
#
# **Symboling** corresponds to the degree to which the auto is more risky than its price indicates. Cars are initially assigned a risk factor symbol associated with its price. Then, if it is more risky (or less), this symbol is adjusted by moving it up (or down) the scale.

# %% [markdown]
# ### Visualizing pairwise relationships in a dataset

# %%
df.sample(4)
# Out:
#      symboling  normalized_losses    make fuel_type aspiration  \
# 109          0                161  peugot    diesel      turbo
# 168          2                134  toyota       gas        std
# 158          0                 91  toyota       gas        std
# 93           1                122  nissan       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 109            four        sedan          rwd           front       107.9
# 168             two  convertible          rwd           front        98.4
# 158            four        sedan          fwd           front        95.7
# 93             four        sedan          fwd           front        94.5
#
#      length  width  height  curb_weight engine_type number_of_cylinders  \
# 109   186.7   68.4    56.7         3252           l                four
# 168   176.2   65.6    53.0         2975         ohc                four
# ...

# %%
sns.pairplot(df[['normalized_losses',"bore","stroke", 'engine_size', 'horsepower']], kind="scatter")

# %%
sns.heatmap(df.corr(),annot=True)
plt.savefig("Heatmap of dataframe.png")
plt.show()

# %% [markdown]
# `insight`
#
# - Heatmap shows that **multicollinearity is present**.

# %% [markdown]
# ### Plotting with categorical data

# %% [markdown]
# #### 3.1 Fuel Type vs Horsepower (Stipplot, Swarmplot, Boxplot)

# %%
sns.set_style("dark")
plt.subplot(131)
sns.stripplot(x=df.fuel_type, y=df.horsepower,linewidth=1)

plt.subplot(132)
sns.swarmplot(x=df.fuel_type, y=df.horsepower,linewidth=1)

plt.subplot(133)
sns.boxplot(x=df.fuel_type, y=df.horsepower,linewidth=1)

plt.savefig("swarmplot of fuel type vs horsepower.png")
plt.show()

# %% [markdown]
# `insight`
#
# - **Gas fuel_type engine is much more than diesel**. The Average of fuel type is for **Gas in nearly 100**.

# %% [markdown]
# #### 3.2 Body_style

# %%
sns.countplot(df["body_style"])
plt.savefig("countplot of body type.png")
plt.show()

# %%
df.number_of_doors.value_counts()
# Out:
# four    114
# two      87
# Name: number_of_doors, dtype: int64

# %%
sns.lineplot(df.body_style, df.number_of_doors,color="r")
plt.savefig("lineplot of body type vs numbers of doors.png")
plt.show()

# %% [markdown]
# `insight`
#
# - **Sedan** is the most popular body style. It typically features **two rows of seats, 4 doors, and a 3-box configuration**. Sedans tend to provide better **fuel economy, affordability, handling, and performance**

# %% [markdown]
# #### 3.3 Normality loss vs Price

# %%
sns.jointplot(data=df, x=df.normalized_losses, y=df.price)
plt.show()

# %%
sns.pointplot(data=df, x=df.normalized_losses, y=df.price)
plt.savefig("lineplot of normalise losses.png")
plt.show()

# %% [markdown]
# `insight`
#
# - **Normalise Rate is high when the price is Low**. Means normalize Loss is maximum in low range price

# %% [markdown]
# ### Drawing multi-panel categorical plots

# %%
sns.factorplot(x="fuel_type", 
               y="horsepower", 
               hue="number_of_doors", 
               col="engine_location", 
               data=df, 
               kind="swarm")
plt.savefig("factorplot of engine location vs fuel type.png")
plt.show()
# Note : we can use catplot() instead of factorplot

# %% [markdown]
# `insight`
#
# - **There is no diesel vehical that have 4 number of_doors** but engine location is rear.
# - **There are 3 gas vehicals that have 2 number of_doors** but engine location is rear.
# - **There are 2 diesel vehicals that have 2 number of_doors** but engine location is front.
# - **More number of diesel vehicals that have 2 and 4 number of doors** but engine location is front.

# %% [markdown]
# ### Function to draw linear regression models
#
# lmplot() is one of the most widely used function to quickly plot the Linear Relationship b/w 2 variables

# %%
sns.lmplot(x="horsepower",y="peak_rpm",data=df)
plt.show()

# %%
sns.lmplot("horsepower","peak_rpm",hue="fuel_type", data=df)
plt.savefig("scatterplot of horsepower vs peak rpm.png")
plt.show()

# %% [markdown]
# `insight`
#
# - The **Regression Plot shows that Gas vehicals are more than Diesel Vehicals**.
#
# - **RPM increases with horsepower is increases**.

# %% [markdown]
# ## 5. Conclusion

# %% [markdown]
# - Biggest market captured by **toyota (15.92)**
#
#
# - Top 5 brand : **Toyota, Nissan, Mazda, Mitshubishi, Honda**.
#
#
# - **Very Less Numbers of vechical which horsepower is Greater than 200**
#
#
# - **Gas Vehicals** demand is more than **Diesel Vehicals**.
#
#
# - Mostly uses two type of fuel engine **(mpfi and 2bbl)**
#
#
# - **Most of the Vehical are made up with Font Engine, Which share is 98.51%**.
#
#
# - **Horsepower of Automobile (Cars) is depend on the engine size of vehical**.
#
#
# - **Sedan is the most popular body style. It typically features two rows of seats, 4 doors, and a 3-box configuration. Sedans tend to provide better fuel economy, affordability, handling, and performance**.
